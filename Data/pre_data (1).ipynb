# %%
import pathlib
import pandas as pd
import numpy as np
import os

import h3

# %%
EGRUL=pd.read_excel('./data/Реестр ЕГРЮЛ г.Челябинск.xlsx', sheet_name=0)
EGRUL
# Out:
#                            Название         ИНН        КПП  \
# 0                        ПАО "ЧТПЗ"  7449006730  744901001
# 1          ООО "НОВАТЭК- ЧЕЛЯБИНСК"  7404056114  745301001
# 2                         АО "ЧЭМК"  7447010227  744701001
# 3              ООО "УРАЛЭНЕРГОСБЫТ"  7453313477  745301001
# 4                          АО "ЧЦЗ"  7448000013  744801001
# ...                             ...         ...        ...
# 99995                 ООО "КВАДРАТ"  7447278619  744701001
# 99996         ООО "ГЕРМЕС 74 ТРЕЙД"  7447278658  744701001
# 99997  ООО "УРАЛЬСКАЯ ДЕЛОВАЯ ЛИГА"  7447278577  744701001
# 99998                  ООО "КЛЕВЕР"  7447278601  744701001
# 99999                  ООО "ГЕЛИОН"  7452145396  745201001
#
#                                                    Адрес Фамилия руководителя  \
# 0      454129, г. Челябинск, ул. Машиностроителей, д....
# 1              454091, г. Челябинск, пр-кт Ленина, 42, А            Ромасенко
# 2      454081, г. Челябинск, ул. Героев Танкограда, д...          Ходоровский
# 3      454090, г. Челябинск, пр-кт Ленина, д. 28Д, ЭТ...             Батраков
# 4        454008, г. Челябинск, Свердловский тракт, д. 24
# ...                                                  ...                  ...
# 99995  454084, г. Челябинск, ул. Каслинская, д. 77, п...              Комаров
# 99996  454021, г.Челябинск, ул.Молодогвардейцев, д.62...             Шахматов
# 99997  454081, г. Челябинск, пр-кт Победы, д. 127, КВ...           Пчелинцева
# 99998  454084, г. Челябинск, ул. Каслинская, д. 77, п...              Комаров
# 99999  454077, г. Челябинск, ул. Мамина, д. 17, пом 1...             Поленова
#
#       Имя руководителя Отчество руководителя  \
# 0
# 1                Вадим          Владимирович
# 2                Павел             Яковлевич
# 3            Александр          Владимирович
# 4
# ...                ...                   ...
# 99995        Александр         Александрович
# 99996            Денис              Олегович
# 99997           Лариса          Вячеславовна
# 99998        Александр         Александрович
# 99999        Екатерина               Юрьевна
#
#                                   Вид деятельности  \
# 0                                    Металлопрокат
# 1                             Топливо и Энергетика
# 2                                  Металлы, сплавы
# 3                                   Электроэнергия
# 4                                  Металлы, сплавы
# ...                                            ...
# 99995        Бытовая химия, косметика и парфюмерия
# 99996  Продукция мукомольной промышленности, крупы
# 99997                       Услуги в области права
# 99998                           Клининговые услуги
# 99999        Услуги в розничной и оптовой торговле
#
#                                                 Телефоны  \
# 0      8 (800) 234-50-05, 8 (351) 255-73-33, 8 (351) ...
# 1      8 (800) 700-80-74, 8 (351) 247-48-48, 8 (351) ...
# 2                   8 (351) 772-63-10, 8 (351) 772-92-75
# 3      8 (351) 259-64-59, 8 (351) 214-87-65, 8 (351) ...
# 4      8 (351) 799-00-09, 8 (351) 799-00-00, 8 (351) ...
# ...                                                  ...
# 99995                                                NaN
# 99996                                                NaN
# 99997                                                NaN
# 99998                                                NaN
# 99999                                                NaN
#
#                                                    email      Выручка  \
# 0      info@chelpipe.ru, konstantin.panchenko@chelpip...  91827610000
# 1      dispetcher@novatek74.ru, gaz@rg74.novatek.ru, ...  58298220000
# 2      info@chemk.ru, romodin@chemk.ru, hodorovskij@c...  48985630000
# 3      alena.kondratyeva@uralsbyt.ru, uralsbyt@esk-ur...  48864110000
# 4      io@zinc.ru, vab@zinc.ru, eib@zinc.ru, v.korotk...  26649230000
# ...                                                  ...          ...
# 99995                                                NaN
# 99996                                                NaN
# 99997                                                NaN
# 99998                                                NaN
# 99999                                                NaN
#
#           Стоимость                               Идентификатор ЭДО      ОКПО  \
# 0      148782400000  2BM-7449006730-2012100411135375991900000000000  00186654
# 1        8303329000  2BM-7404056114-2012101009483684385930000000000  68628371
# 2       27405640000             2BEffd3247cd22a4c14bfdf84e401ca79bd  00186507
# 3        1834573000             2BE72fdef7b2bd741929636c5b94ddfe68b  19151032
# 4       35213190000  2BM-7448000013-2013022202504047094690000000000  00194228
# ...             ...                                             ...       ...
# 99995                           2BEdf505a0817464ba39169be1649ca38e5
# 99996
# 99997                                                                20120798
# 99998                           2BE4754df052057405480ba01585e6923fe
# 99999
#
#       Рег. номер ПФ Код филиала                             Сайт  \
# 0      084003000004              chelpipe.ru, market.chelpipe.ru
# 1      084001068391                                 novatek74.ru
# 2      084005000002                                     chemk.ru
# 3      084001085459                                          NaN
# 4      084006001095                                      zinc.ru
# ...             ...         ...                              ...
# 99995  084005097702                                          NaN
# 99996  084005097706                                          NaN
# 99997  084005097707                                          NaN
# 99998  084005097703                                          NaN
# 99999  084004077936                                          NaN
#
#               ЕГАИС GLN
# 0
# 1
# 2
# 3
# 4      030000095411
# ...             ...  ..
# 99995
# 99996
# 99997
# 99998
# 99999
#
# [100000 rows x 19 columns]

# %%
EGRUL['Вид деятельности'].unique()
# Out:
# array(['Металлопрокат', 'Топливо и Энергетика', 'Металлы, сплавы',
#        'Электроэнергия', 'Бытовая техника, часы',
#        'Твердое топливо, торф, кокс, уголь', 'Услуги металлообработки',
#        'Продукты', 'Банковские и финансовые услуги, кредит',
#        'Теплоэнергия', 'Мясо, мясные продукты, консервы мясные',
#        'Автотранспорт', 'Строительно-монтажные работы',
#        'Хлебобулочные и кондитерские изделия, сахар',
#        'Ремонт, монтаж и обслуживание машин и технологического оборудования',
#        'Молочная продукция', 'Макаронные изделия',
#        'Строительство, ремонт и обслуживание дорог, мостов, тоннелей, аэродромов и ЖД путей',
#        'Компрессоры, насосное и водонапорное оборудование',
#        'Медицинское оборудование и техника', 'Алкогольные напитки',
#        'Розничная торговля', 'Автозаправки',
#        'Контрольно-измерительные приборы (КИП)',
#        'Готовые металлоизделия и металлоконструкции',
#        'Бетон, цемент, известь, гипс',
#        'Услуги в розничной и оптовой торговле',
#        'Металлолом, отходы металлические',
#        'Авиационное, реактивное топливо',
#        'Водопроводное и газовое оборудование',
#        'Строительство, ремонт и реконструкция зданий и сооружений',
#        'Оборудование и системы очистки',
#        'Бытовая химия, косметика и парфюмерия',
#        'Торговля производственным оборудованием (станки, машины, механизмы ...)',
#        'Электромонтажные работы', 'Автосалоны', 'Защита окружающей среды',
#        'Продукты питания и напитки прочие', 'Плодоовощная продукция',
#        'Электродвигатели, генераторы, трансформаторы',
#        'Материалы и изделия для строительных и отделочных работ',
#        'Медицинские учреждения', 'Стекло и изделия из стекла',
#        'Химические соединения, реактивы, химикаты различного назначения',
#        'Оборудование нефтепромысловое, горно-добывающее, буровое',
#        'Перевозки грузовые', 'Услуги трубопроводного транспорта',
#        'Запчасти для транспорта, двигатели, аксеcсуары',
#        'Литейное производство',
#        'Напитки алкогольные, напитки из солода и солод',
#        'Транспортные услуги прочие', 'Прицепы, полуприцепы, кузова',
#        'Оборудование и машины общего и специального назначения',
#        'Управление проектами строительства, строительный контроль',
#        'Рыба, рыбные продукты, консервы рыбные, морепродукты',
#        'Фармацевтические и лекарственные препараты, лекарственное сырье',
#        'Швейные, текстильные и трикотажные изделия прочие',
#        'Строительство, ремонт и обслуживание трубопроводов, сетей водоснабжения, канализации и отопления',
#        'Аренда и лизинг недвижимости, обмен, приватизация',
#        'Напитки безалкогольные, вода', 'Наземные перевозки',
#        'Автосервисы, шиномонтаж', 'Аптеки', 'Металлы и металлоизделия',
#        'Химическая промышленность', 'Проектирование и документация',
#        'Одежда, спецодежда, форменная одежда',
#        'Электротехнические материалы и электрооборудование прочее',
#        'Бумага, картон', 'Сантехника', 'Игры и игрушки',
#        'Связь и коммуникации',
#        'Продукция мукомольной промышленности, крупы',
#        'Грузоподъемное, такелажное и лифтовое оборудование',
#        'Управление недвижимостью',
#        'Электрораспределительное оборудование и аппаратура контроля',
#        'Газ, газообразное топливо, конденсат газовый',
#        'Мебель (для дома, офиса, прочая)',
#        'Продукция лесопильной промышленности',
#        'Компьютеры и комплектующие, вычислительная техника, оргтехника',
#        'Подготовка строительного участка, разборка и снос зданий',
#        'Автозапчасти', 'Офис, дом',
#        'Книги, газеты, журналы и прочая продукция издательств',
#        'Песок, глина, камень, щебень и прочие виды минерального сырья',
#        'Растительные и животные масла и жиры', 'Соль, специи',
#        'Пробка, смолы, прочая продукция лесопереработки',
#        'Краски, лаки, эмали, клеи',
#        'Хозяйственные товары, товары широкого потребления',
#        'Перевозки, логистика, таможня',
#        'Корм для животных, кормовые добавки, комбикорма',
#        'Полимерные материалы, пластмассовые изделия',
#        'Рестораны, кафе, столовые', 'Химические продукты прочие',
#        'Медицинские, ортопедические изделия, оптика',
#        'Научные исследования и разработки', 'Красота и здоровье',
#        'Прочее в разделе сельское хозяйство, охота, рыболовство',
#        'Экспертные и оценочные услуги', 'Изделия из бумаги и картона',
#        'Реклама, СМИ, телевидение', 'Оборудование и средства связи',
#        'Цистерны, резервуары, тара металлическая', 'Развлечения',
#        'Бытовая техника, электроника, фототехника',
#        'Программное обеспечение',
#        'Строительство, ремонт и обслуживание объектов энергетики, электрических сетей, линий связи',
#        'Строительство, ремонт и обслуживание водных путей и гидросооружений',
#        'Агрохимия и удобрения', 'Прочие транспортные средства',
#        'Отходы неметаллические, вторичное сырье',
#        'Торговля бытовыми изделиями',
#        'Услуги, связанные с добычей нефти, газа, угля, торфа',
#        'Минералы, продукция горнодобывающей промышленности',
#        'Геодезические, картографические и кадастровые работы',
#        'Животноводство и охотничьи хозяйства', 'Аккумуляторы, батареи',
#        'Охранные услуги, обеспечение безопасности',
#        'Цветы, семена, саженцы', 'Железнодорожные перевозки',
#        'Машины и оборудование для металлургической отрасли',
#        'Аренда строительного оборудования и техники',
#        'Одежда, обувь, аксессуары',
#        'Газогенераторы, промышленные кондиционеры, вентиляционное и холодильное оборудование',
#        'Руды металлические', 'Локомотивостроение и вагоностроение',
#        'Телефонная связь', 'Огнеупорные материалы',
#        'Инструмент, оснастка', 'Прочие услуги',
#        'Котлы отопительные, котельное и теплообменное оборудование',
#        'Посуда, домашняя утварь, предметы интерьера',
#        'Образование и курсы',
#        'Ремонт, установка и техническое обслуживание офисной и вычислительной техники',
#        'Бумажная и картонная тара', 'Спорт, туризм',
#        'Торговля топливом (газ, уголь, торф ...)',
#        'Логистические услуги, хранение грузов, экспедиторские услуги, таможенные услуги',
#        'Стоматология', 'Полиграфические услуги', 'Кровельные работы',
#        'Сельскохозяйственные работы и услуги',
#        'Компьютеры, офисная техника, ПО', 'Ювелирные изделия, часы',
#        'Светотехническое оборудование, электрические лампы',
#        'Купля-продажа жилых и нежилых зданий, сооружений и помещений',
#        'Электротехника',
#        'Услуги по аренде техники, оборудования, бытовых товаров и предметов личного пользования',
#        'Клининговые услуги', 'Бытовая химия, косметика, парфюмерия',
#        'Мягкий инвентарь, постельные принадлежности', 'Недвижимость',
#        'Дистанционная торговля', 'Услуги в области права',
#        'Почтовая и курьерская связь', 'Отделочные работы',
#        'Канцелярские товары', 'Зоотовары',
#        'Мясо, мясные продукты, мясные консервы',
#        'Создание и сопровождение компьютерных баз данных, электронных информационных ресурсов',
#        'Украшения, ювелирная продукция, наградная продукция',
#        'Ремонт бытовых изделий, техники и предметов личного пользования',
#        'Обувь', 'Мебель', 'Маркетинговые и социальные исследования',
#        'Услуги по сертификации продукции и аттестации производств',
#        'Хлебобулочные и кондитерские изделия, десерты, сахар',
#        'Компьютерная техника, периферия, ПО', 'Защита информации',
#        'Гостиницы, организация проживания', 'Занятия спортом',
#        'Резина и изделия из резины', 'Такси',
#        'Торговля медицинскими изделиями и фармацией',
#        'Услуги в области технической и коммерческой деятельности',
#        'Монтаж, ремонт и обслуживание оборудования связи', 'Станки',
#        'Аудио, видео, фототехника, проекционное оборудование, оптические приборы',
#        'Спортивные товары, оборудование, инвентарь', 'Чай, кофе, какао',
#        'Ритуальные услуги', 'Услуги кадровых агентств',
#        'Услуги туристических агентств', 'Водный транспорт',
#        'Сельскохозяйственный инвентарь и вспомогательное оборудование',
#        'Услуги прачечных, химчисток', 'Медицинский инструмент',
#        'Строительные материалы, товары для ремонта',
#        'Электронные компоненты',
#        'Табак, табачные изделия и продукты табачной промышленности',
#        'Кабели и провода', 'Бухгалтерский учет, аудит',
#        'Страхование, пенсионное обеспечение', 'Бытовые услуги',
#        'Аренда и лизинг транспортных средств',
#        'Деревянные конструкции и изделия из дерева',
#        'Производство промышленных роботов и робототехнических устройств',
#        'Детское и диетическое питание',
#        'Тракторное и сельскохозяйственное машиностроение',
#        'Услуги связанные с лесозаготовками и лесоводством',
#        'Аренда, лизинг транспорта', 'Оружие, боеприпасы, вооружение',
#        'Теплоизоляция, гидроизоляция, экранирование помещений',
#        'Энергетические установки, турбины и прочее энергетическое оборудование',
#        'Рыбоводство и рыболовство', 'Комиссионные товары',
#        'Фото, видео, звукозапись', 'Взрывчатые вещества, фейерверки',
#        'Растениеводство',
#        'Аренда и управление собственным или арендованным торговым объектом недвижимого имущества',
#        'Нефтяные масла, смазки, суспензии', 'Шины, диски, покрышки',
#        'Санатории и оздоровительные учреждения', 'Автостоянки',
#        'Авиа- и космическое машиностроение',
#        'Парикмахерские, салоны красоты',
#        'Машины и оборудование для пищевой промышленности и общественного питания',
#        'Птица, яйцо, субпродукты', 'Овощи, фрукты, орехи',
#        'Детали, узлы и комплектующие изделия общемашиностроительного применения',
#        'Услуги по геологическим и геофизическим изысканиям, картография',
#        'Термическое, электротермическое оборудование и печи',
#        'Бизнес, финансы, страхование, маркетинг',
#        'Дезинфекция, дезинсекция, дератизация',
#        'Социальные услуги и страхование',
#        'Услуги по пошиву и ремонту одежды, текстильных изделий',
#        'Машины и оборудование для легкой промышленности',
#        'Носители информации', 'Книги, журналы, печатная продукция',
#        'Цветы', 'Услуги по предоставлению лицензий',
#        'Услуги связи прочие', 'Техническая инвентаризация',
#        'Изделия из кожи и меха (кроме одежды и обуви)',
#        'Сувенирная продукция', 'Станции технического осмотра',
#        'Водные перевозки', 'Автомойки', 'Табачная продукция',
#        'Бензин, дизельное топливо, светлые нефтепродукты',
#        'Телевидение, радиовещание', 'Монтаж и ремонт ограждений',
#        'Изделия художественных промыслов, предметы искусства, предметы коллекционирования',
#        'Купля-продажа земли', 'Кожа, мех', 'Музыкальные инструменты',
#        'Прочие перевозки', 'Ветеринарные клиники',
#        'Целлюлоза, масса древесная', 'Хранилища, сейфы',
#        'Спорт, отдых, туризм, культура', 'Религиозные организации',
#        'Запорно-пломбировочные изделия',
#        'Продукты питания, напитки, табак', 'Массажные салоны',
#        'Государственные органы', 'Рыба, рыбные консервы, морепродукты',
#        'Авиаперевозки', 'Нефть и нефтесырье', ' ',
#        'Кино и фотопленка, фотохимикаты', 'Помощь на дорогах, эвакуация',
#        'Деятельность по организации отдыха детей и их оздоровления',
#        'Вывоз, утилизация и переработка мусора, твердых и жидких отходов',
#        'Суды'], dtype=object)

# %%
EGRUL_my=EGRUL[['Название','ИНН','Адрес', 'Вид деятельности','Телефоны']]

# %%
EGRUL_my
# Out:
#                            Название         ИНН  \
# 0                        ПАО "ЧТПЗ"  7449006730
# 1          ООО "НОВАТЭК- ЧЕЛЯБИНСК"  7404056114
# 2                         АО "ЧЭМК"  7447010227
# 3              ООО "УРАЛЭНЕРГОСБЫТ"  7453313477
# 4                          АО "ЧЦЗ"  7448000013
# ...                             ...         ...
# 99995                 ООО "КВАДРАТ"  7447278619
# 99996         ООО "ГЕРМЕС 74 ТРЕЙД"  7447278658
# 99997  ООО "УРАЛЬСКАЯ ДЕЛОВАЯ ЛИГА"  7447278577
# 99998                  ООО "КЛЕВЕР"  7447278601
# 99999                  ООО "ГЕЛИОН"  7452145396
#
#                                                    Адрес  \
# 0      454129, г. Челябинск, ул. Машиностроителей, д....
# 1              454091, г. Челябинск, пр-кт Ленина, 42, А
# 2      454081, г. Челябинск, ул. Героев Танкограда, д...
# 3      454090, г. Челябинск, пр-кт Ленина, д. 28Д, ЭТ...
# 4        454008, г. Челябинск, Свердловский тракт, д. 24
# ...                                                  ...
# 99995  454084, г. Челябинск, ул. Каслинская, д. 77, п...
# 99996  454021, г.Челябинск, ул.Молодогвардейцев, д.62...
# 99997  454081, г. Челябинск, пр-кт Победы, д. 127, КВ...
# 99998  454084, г. Челябинск, ул. Каслинская, д. 77, п...
# 99999  454077, г. Челябинск, ул. Мамина, д. 17, пом 1...
#
#                                   Вид деятельности  \
# 0                                    Металлопрокат
# 1                             Топливо и Энергетика
# 2                                  Металлы, сплавы
# 3                                   Электроэнергия
# 4                                  Металлы, сплавы
# ...                                            ...
# 99995        Бытовая химия, косметика и парфюмерия
# 99996  Продукция мукомольной промышленности, крупы
# 99997                       Услуги в области права
# 99998                           Клининговые услуги
# 99999        Услуги в розничной и оптовой торговле
#
#                                                 Телефоны
# 0      8 (800) 234-50-05, 8 (351) 255-73-33, 8 (351) ...
# 1      8 (800) 700-80-74, 8 (351) 247-48-48, 8 (351) ...
# 2                   8 (351) 772-63-10, 8 (351) 772-92-75
# 3      8 (351) 259-64-59, 8 (351) 214-87-65, 8 (351) ...
# 4      8 (351) 799-00-09, 8 (351) 799-00-00, 8 (351) ...
# ...                                                  ...
# 99995                                                NaN
# 99996                                                NaN
# 99997                                                NaN
# 99998                                                NaN
# 99999                                                NaN
#
# [100000 rows x 5 columns]

# %%
doc1=pd.read_excel('data/20.10.2021 Реестр лицензий на заготовку, хранение, переработку и реализацию лома черных металлов, цветных металлов.xlsx', sheet_name=0,header=2)
doc1=doc1[pd.isnull(doc1['Основание и дата прекращения\nдействия лицензии\n'])]
doc1
# Out:
#      № п/п  Регистрационный номер  \
# 0      1.0                    1.0
# 3      4.0                    4.0
# 4      5.0                    5.0
# 5      6.0                    6.0
# 8      5.0                    9.0
# ..     ...                    ...
# 460  417.0                  487.0
# 461  418.0                  488.0
# 462  419.0                  489.0
# 463  420.0                  490.0
# 464  421.0                  491.0
#
#                            Серия лицензии, дата выдачи  \
# 0                     Ч 740002              23.12.2011
# 3         Ч 740003\n23.12.2011\n\nЧ 740577\n29.03.2019
# 4    Д 454867\n09.09.2009\n\n\n\nЧ 740004\n23.12.20...
# 5    Д 455038\n22.09.2010\n\nД 455110\n19.05.2011\n...
# 8                               Ч 740022\n22.03.2012\n
# ..                                                 ...
# 460                                2021-09-13 00:00:00
# 461                                2021-09-16 00:00:00
# 462                                2021-09-16 00:00:00
# 463                                2021-09-22 00:00:00
# 464                                2021-10-08 00:00:00
#
#                     Наименование лицензирующего органа  \
# 0                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 8                                                  NaN
# ..                                                 ...
# 460  Министерство промышленности, новых технологий ...
# 461  Министерство промышленности, новых технологий ...
# 462  Министерство промышленности, новых технологий ...
# 463  Министерство промышленности, новых технологий ...
# 464  Министерство промышленности, новых технологий ...
#
#                 Основания решения\n о\nвыдаче лицензии  \
# 0                           Приказ № 140 от 23.12.2011
# 3    Приказ № 385 от 23.12.2011\n\nПриказ № 385 от ...
# 4    Приказ № 91 от 09.09.2009\n\n\n\nПриказ № 385 ...
# 5    Приказ № 286 от 22.09.2010\n\nПриказ № 328 от ...
# 8                            Приказ № 01 от 22.03.2012
# ..                                                 ...
# 460                         Приказ № 428 от 13.09.2021
# 461                         Приказ № 439 от 16.09.2021
# 462                         Приказ № 441 от 16.09.2021
# 463                         Приказ № 443 от 22.09.2021
# 464                         Приказ № 459 от 08.10.2021
#
#     Основание и дата прекращения\nдействия лицензии\n  \
# 0                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 8                                                 NaN
# ..                                                ...
# 460                                               NaN
# 461                                               NaN
# 462                                               NaN
# 463                                               NaN
# 464                                               NaN
#
#     Наименование предприятия (полное и (в случае, если имеется) сокращенное наименование, организационно-правовая форма)  \
# 0                                    ООО «УралВторМет»
# 3    ООО «Профит-мет»\n\n                          ...
# 4    ООО «Мечел-Материалы»\n\n                     ...
# 5    ООО «Урал-КЭМ»\n\n                            ...
# 8                 ЗАО Машиностроительный завод «Метаб»
# ..                                                 ...
# 460  Общество с ограниченной ответственностью "Урал...
# 461  Общество с ограниченной ответственностью "Нефт...
# 462  Общество с ограниченной ответственностью "ТЕМБ...
# 463  Общество с ограниченной ответственностью "Челя...
# 464  Общество с ограниченной ответственностью "Атла...
#
#              ИНН            ОГРН  \
# 0    7415073915    1117415004145
# 3    7438021085\n1067438012718\n
# 4      5003064770\n1075003000324
# 5    7450028496\n1027402819190\n
# 8    7448028234\n1027402541638\n
# ..                           ...
# 460   7451455109   1217400017691
# 461   7451319547   1117451005869
# 462   7839140322   1217800068210
# 463    7449126805  1157449004877
# 464    7447073393  1047421512269
#
#                                              Вид работ  \
# 0                                           черный лом
# 3                                           черный лом
# 4                        черный лом\n\nцветной \nлом\n
# 5                        черный лом\n\nцветной \nлом\n
# 8                               черный лом цветной лом
# ..                                                 ...
# 460  заготовка, хранение, переработка и реализация ...
# 461  заготовка, хранение, переработка и реализация ...
# 462  заготовка, хранение, переработка и реализация ...
# 463  заготовка, хранение, переработка и реализация ...
# 464  заготовка, хранение, переработка и реализация ...
#
#     Основания и даты проведения проверок лицензиатов и реквизиты актов, составленных по результатам проведенных проверок\n  \
# 0    Приказ № 210-ПЛ от 13.10.2014, Акт проверки № ...
# 3    Распоряжение № 145-ПР от 22.11.2011, Акт прове...
# 4    Распоряжение № 74-ПЛ от 02.07.2012, Акт провер...
# 5    Распряжение № 107-ПЛ от 05.09.2011, Акт провер...
# 8    Приказ № 33-ПЛ от 07.04.2014, Акт проверки № 2...
# ..                                                 ...
# 460                                                NaN
# 461                                                NaN
# 462                                                NaN
# 463                                                NaN
# 464                                                NaN
#
#      Основания, даты вынесения решений лицензирующего органа о приостановлении, о возобновлении действия лицензий и реквизиты таких решений\n  \
# 0                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 8                                                  NaN
# ..                                                 ...
# 460                                                NaN
# 461                                                NaN
# 462                                                NaN
# 463                                                NaN
# 464                                                NaN
#
#                                      Юридический адрес  \
# 0                              г. Миасс, ул. МЖК, д. 1
# 3    Сосновский район,\nп. Есаульский, ул. Заготзер...
# 4    Московская область, Ленинский район, \nг. Видн...
# 5    г. Челябинск,\nул. Мира, д. 10\n\n\nг. Челябин...
# 8                 г. Челябинск,\nул. Автодорожная, 10а
# ..                                                 ...
# 460  454053,                      г. Челябинск, ули...
# 461  454001, г. Челябинск,                  ул. Бра...
# 462  190020, г. Санкт-Петербург, Старо-Петергофский...
# 463  454010, Челябинская обл., г. Челябинск, ул. Ен...
# 464  454053, Челябинская обл., г. Челябинск, тракт ...
#
#                                             Телефон  \
# 0                                   8(3513)56-62-82
# 3                                         233-45-91
# 4                    (495)\n221-88-88\nдоб. 63612\n
# 5                           247-41-36;\n247-41-37\n
# 8                                         791-76-93
# ..                                              ...
# 460                                 8-908-066-20-66
# 461                                           -1668
# 462                                 8-912-479-55-55
# 463                               8 (351) 267-47-47
# 464  8 (351) 214-14-15            8 (351) 247-37-22
#
#                       Место осуществления деятельности
# 0                             г. Миасс, ул. Силовая, 1
# 3    1. Сосновский район, \nп. Есаульский,\n ул. За...
# 4    1. г. Челябинск, в районе трамвайного кольца «...
# 5    1. г. Челябинск,\nул.Строительная, 21 (черный,...
# 8             г. Челябинск,\nул. Автодорож\nная, д. 10
# ..                                                 ...
# 460  454053, г. Челябинск, улица Физкультурная, д. 34.
# 461  454015, г. Челябинск,                         ...
# 462  454053, г. Челябинск,                         ...
# 463  454010, Челябинская обл., г. Челябинск, ул. Ен...
# 464  454053, Челябинская обл., г. Челябинск, тракт ...
#
# [392 rows x 14 columns]

# %%
doc1.columns
# Out:
# Index(['№ п/п', 'Регистрационный номер', 'Серия лицензии, дата выдачи',
#        'Наименование лицензирующего органа',
#        'Основания решения\n о\nвыдаче лицензии',
#        'Основание и дата прекращения\nдействия лицензии\n',
#        'Наименование предприятия (полное и (в случае, если имеется) сокращенное наименование, организационно-правовая форма)',
#        'ИНН            ОГРН', 'Вид работ',
#        'Основания и даты проведения проверок лицензиатов и реквизиты актов, составленных по результатам проведенных проверок\n',
#        'Основания, даты вынесения решений лицензирующего органа о приостановлении, о возобновлении действия лицензий и реквизиты таких решений\n',
#        'Юридический адрес', 'Телефон', 'Место осуществления деятельности'],
#       dtype='object')

# %%
doc1_my=doc1[['Наименование предприятия (полное и (в случае, если имеется) сокращенное наименование, организационно-правовая форма)','ИНН            ОГРН','ИНН            ОГРН','Вид работ','Место осуществления деятельности']]
doc1_my.columns=['name','inn','ogrn','type','adres']

doc1_my
# Out:
#                                                   name  \
# 0                                    ООО «УралВторМет»
# 3    ООО «Профит-мет»\n\n                          ...
# 4    ООО «Мечел-Материалы»\n\n                     ...
# 5    ООО «Урал-КЭМ»\n\n                            ...
# 8                 ЗАО Машиностроительный завод «Метаб»
# ..                                                 ...
# 460  Общество с ограниченной ответственностью "Урал...
# 461  Общество с ограниченной ответственностью "Нефт...
# 462  Общество с ограниченной ответственностью "ТЕМБ...
# 463  Общество с ограниченной ответственностью "Челя...
# 464  Общество с ограниченной ответственностью "Атла...
#
#                              inn                         ogrn  \
# 0    7415073915    1117415004145  7415073915    1117415004145
# 3    7438021085\n1067438012718\n  7438021085\n1067438012718\n
# 4      5003064770\n1075003000324    5003064770\n1075003000324
# 5    7450028496\n1027402819190\n  7450028496\n1027402819190\n
# 8    7448028234\n1027402541638\n  7448028234\n1027402541638\n
# ..                           ...                          ...
# 460   7451455109   1217400017691   7451455109   1217400017691
# 461   7451319547   1117451005869   7451319547   1117451005869
# 462   7839140322   1217800068210   7839140322   1217800068210
# 463    7449126805  1157449004877    7449126805  1157449004877
# 464    7447073393  1047421512269    7447073393  1047421512269
#
#                                                   type  \
# 0                                           черный лом
# 3                                           черный лом
# 4                        черный лом\n\nцветной \nлом\n
# 5                        черный лом\n\nцветной \nлом\n
# 8                               черный лом цветной лом
# ..                                                 ...
# 460  заготовка, хранение, переработка и реализация ...
# 461  заготовка, хранение, переработка и реализация ...
# 462  заготовка, хранение, переработка и реализация ...
# 463  заготовка, хранение, переработка и реализация ...
# 464  заготовка, хранение, переработка и реализация ...
#
#                                                  adres
# 0                             г. Миасс, ул. Силовая, 1
# 3    1. Сосновский район, \nп. Есаульский,\n ул. За...
# 4    1. г. Челябинск, в районе трамвайного кольца «...
# 5    1. г. Челябинск,\nул.Строительная, 21 (черный,...
# 8             г. Челябинск,\nул. Автодорож\nная, д. 10
# ..                                                 ...
# 460  454053, г. Челябинск, улица Физкультурная, д. 34.
# 461  454015, г. Челябинск,                         ...
# 462  454053, г. Челябинск,                         ...
# 463  454010, Челябинская обл., г. Челябинск, ул. Ен...
# 464  454053, Челябинская обл., г. Челябинск, тракт ...
#
# [392 rows x 5 columns]

# %%
doc2=pd.read_excel('./data/Реестр лицензий на обращение с отходами 1.xls', sheet_name=0,header=1)
doc2=doc2[pd.isnull(doc2['Unnamed: 13'])]
doc2=doc2.dropna(subset=['Наименование предприятия (полное, сокращенное, фирменное), ФИО индивидуального предпринимателя'])
doc2
# Out:
#        Unnamed: 0                                         Unnamed: 1  \
# 0             1.0  Управление Росприроднадзора по Челябинской обл...
# 1             1.0  Управление Росприроднадзора по Челябинской обл...
# 2             1.0  Управление Росприроднадзора по Челябинской обл...
# 3             1.0  Управление Росприроднадзора по Челябинской обл...
# 4             1.0  Управление Росприроднадзора по Челябинской обл...
# ...           ...                                                ...
# 41687       611.0  Уральское межрегиональное управление Росприрод...
# 41688       611.0  Уральское межрегиональное управление Росприрод...
# 41689       611.0  Уральское межрегиональное управление Росприрод...
# 41690       611.0  Уральское межрегиональное управление Росприрод...
# 41691       611.0  Уральское межрегиональное управление Росприрод...
#
#       Наименование предприятия (полное, сокращенное, фирменное), ФИО индивидуального предпринимателя  \
# 0      ОАО "Челябинский завод прифилированного стальн...
# 1      ОАО "Челябинский завод прифилированного стальн...
# 2      ОАО "Челябинский завод прифилированного стальн...
# 3      ОАО "Челябинский завод прифилированного стальн...
# 4      ОАО "Челябинский завод прифилированного стальн...
# ...                                                  ...
# 41687       Межмуниципальное ООО «Катав-Ивановское АТП»
# 41688       Межмуниципальное ООО «Катав-Ивановское АТП»
# 41689       Межмуниципальное ООО «Катав-Ивановское АТП»
# 41690       Межмуниципальное ООО «Катав-Ивановское АТП»
# 41691       Межмуниципальное ООО «Катав-Ивановское АТП»
#
#                                                    Адрес  \
# 0                          г.Челябинск, ул.Валдайская, 7
# 1                          г.Челябинск, ул.Валдайская, 7
# 2                          г.Челябинск, ул.Валдайская, 7
# 3                          г.Челябинск, ул.Валдайская, 7
# 4                          г.Челябинск, ул.Валдайская, 7
# ...                                                  ...
# 41687  456110, Челябинская область, Катав-Ивановск, П...
# 41688  456110, Челябинская область, Катав-Ивановск, П...
# 41689  456110, Челябинская область, Катав-Ивановск, П...
# 41690  456110, Челябинская область, Катав-Ивановск, П...
# 41691  456110, Челябинская область, Катав-Ивановск, П...
#
#                       Телефон          ОГРН    Unnamed: 6 Unnamed: 7  \
# 0              (351)771-09-09  1.027402e+11  7.447015e+09        NaT
# 1              (351)771-09-09  1.027402e+11  7.447015e+09        NaT
# 2              (351)771-09-09  1.027402e+11  7.447015e+09        NaT
# 3              (351)771-09-09  1.027402e+11  7.447015e+09        NaT
# 4              (351)771-09-09  1.027402e+11  7.447015e+09        NaT
# ...                       ...           ...           ...        ...
# 41687  89124030578, 264-75-53  1.127457e+12  7.457001e+09 2019-11-14
# 41688  89124030578, 264-75-53  1.127457e+12  7.457001e+09 2019-11-14
# 41689  89124030578, 264-75-53  1.127457e+12  7.457001e+09 2019-11-14
# 41690  89124030578, 264-75-53  1.127457e+12  7.457001e+09 2019-11-14
# 41691  89124030578, 264-75-53  1.127457e+12  7.457001e+09 2019-11-14
#
#                   Unnamed: 8                Unnamed: 9  ...  \
# 0      13.11.2010-13.11.2015  серия 74         № 00001  ...
# 1      13.11.2010-13.11.2015  серия 74         № 00001  ...
# 2      13.11.2010-13.11.2015  серия 74         № 00001  ...
# 3      13.11.2010-13.11.2015  серия 74         № 00001  ...
# 4      13.11.2010-13.11.2015  серия 74         № 00001  ...
# ...                      ...                       ...  ...
# 41687              бессрочно               (74)-8572-Т  ...
# 41688              бессрочно               (74)-8572-Т  ...
# 41689              бессрочно               (74)-8572-Т  ...
# 41690              бессрочно               (74)-8572-Т  ...
# 41691              бессрочно               (74)-8572-Т  ...
#
#       Код отхода по ФККО Класс опасности отхода  \
# 0          3533010013011                      1
# 1          9211010113012                      2
# 2          5410020202033                      3
# 3          5410020702033                      3
# 4          5410021102033                      3
# ...                  ...                    ...
# 41687   7 36 100 02 72 4                     IV
# 41688   7 36 210 01 72 4                     IV
# 41689   7 39 422 11 72 4                     IV
# 41690   7 39 911 01 72 4                     IV
# 41691   7 39 952 11 71 4                     IV
#
#                                          Unnamed: 17  \
# 0                              размещение (хранение)
# 1             транспортировка, размещение (хранение)
# 2             транспортировка, размещение (хранение)
# 3             транспортировка, размещение (хранение)
# 4             транспортировка, размещение (хранение)
# ...                                              ...
# 41687  Транспортирование отходов IV класса опасности
# 41688  Транспортирование отходов IV класса опасности
# 41689  Транспортирование отходов IV класса опасности
# 41690  Транспортирование отходов IV класса опасности
# 41691  Транспортирование отходов IV класса опасности
#
#                                              Unnamed: 18  \
# 0                    454081,Челябинск, ул. Валдайская, 7
# 1                    454081,Челябинск, ул. Валдайская, 7
# 2                    454081,Челябинск, ул. Валдайская, 7
# 3                    454081,Челябинск, ул. Валдайская, 7
# 4                    454081,Челябинск, ул. Валдайская, 7
# ...                                                  ...
# 41687  456110, Челябинская область, г. Катав-Ивановск...
# 41688  456110, Челябинская область, г. Катав-Ивановск...
# 41689  456110, Челябинская область, г. Катав-Ивановск...
# 41690  456110, Челябинская область, г. Катав-Ивановск...
# 41691  456110, Челябинская область, г. Катав-Ивановск...
#
#       номер и дата проверки номер и дата выездной проверки Unnamed: 21  \
# 0                       NaN                            NaN         NaN
# 1                       NaN                            NaN         NaN
# 2                       NaN                            NaN         NaN
# 3                       NaN                            NaN         NaN
# 4                       NaN                            NaN         NaN
# ...                     ...                            ...         ...
# 41687                   NaN                            NaN         NaN
# 41688                   NaN                            NaN         NaN
# 41689                   NaN                            NaN         NaN
# 41690                   NaN                            NaN         NaN
# 41691                   NaN                            NaN         NaN
#
#       Unnamed: 22 Unnamed: 23 Unnamed: 24
# 0             NaN         NaN         NaN
# 1             NaN         NaN         NaN
# 2             NaN         NaN         NaN
# 3             NaN         NaN         NaN
# 4             NaN         NaN         NaN
# ...           ...         ...         ...
# 41687         NaN         NaN         NaN
# 41688         NaN         NaN         NaN
# 41689         NaN         NaN         NaN
# 41690         NaN         NaN         NaN
# 41691         NaN         NaN         NaN
#
# [35845 rows x 25 columns]

# %%
doc2.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1',
#        'Наименование предприятия (полное, сокращенное, фирменное), ФИО индивидуального предпринимателя',
#        'Адрес', 'Телефон', 'ОГРН', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Наименование отхода', 'Код отхода по ФККО',
#        'Класс опасности отхода', 'Unnamed: 17', 'Unnamed: 18',
#        'номер и дата проверки', 'номер и дата выездной проверки',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24'],
#       dtype='object')

# %%
doc2_my=doc2[['Наименование предприятия (полное, сокращенное, фирменное), ФИО индивидуального предпринимателя','ОГРН','Unnamed: 6','Unnamed: 17','Unnamed: 18']]
doc2_my.columns=['name','inn','ogrn','type','adres']

doc2_my
# Out:
#                                                     name           inn  \
# 0      ОАО "Челябинский завод прифилированного стальн...  1.027402e+11
# 1      ОАО "Челябинский завод прифилированного стальн...  1.027402e+11
# 2      ОАО "Челябинский завод прифилированного стальн...  1.027402e+11
# 3      ОАО "Челябинский завод прифилированного стальн...  1.027402e+11
# 4      ОАО "Челябинский завод прифилированного стальн...  1.027402e+11
# ...                                                  ...           ...
# 41687       Межмуниципальное ООО «Катав-Ивановское АТП»   1.127457e+12
# 41688       Межмуниципальное ООО «Катав-Ивановское АТП»   1.127457e+12
# 41689       Межмуниципальное ООО «Катав-Ивановское АТП»   1.127457e+12
# 41690       Межмуниципальное ООО «Катав-Ивановское АТП»   1.127457e+12
# 41691       Межмуниципальное ООО «Катав-Ивановское АТП»   1.127457e+12
#
#                ogrn                                           type  \
# 0      7.447015e+09                          размещение (хранение)
# 1      7.447015e+09         транспортировка, размещение (хранение)
# 2      7.447015e+09         транспортировка, размещение (хранение)
# 3      7.447015e+09         транспортировка, размещение (хранение)
# 4      7.447015e+09         транспортировка, размещение (хранение)
# ...             ...                                            ...
# 41687  7.457001e+09  Транспортирование отходов IV класса опасности
# 41688  7.457001e+09  Транспортирование отходов IV класса опасности
# 41689  7.457001e+09  Транспортирование отходов IV класса опасности
# 41690  7.457001e+09  Транспортирование отходов IV класса опасности
# 41691  7.457001e+09  Транспортирование отходов IV класса опасности
#
#                                                    adres
# 0                    454081,Челябинск, ул. Валдайская, 7
# 1                    454081,Челябинск, ул. Валдайская, 7
# 2                    454081,Челябинск, ул. Валдайская, 7
# 3                    454081,Челябинск, ул. Валдайская, 7
# 4                    454081,Челябинск, ул. Валдайская, 7
# ...                                                  ...
# 41687  456110, Челябинская область, г. Катав-Ивановск...
# 41688  456110, Челябинская область, г. Катав-Ивановск...
# 41689  456110, Челябинская область, г. Катав-Ивановск...
# 41690  456110, Челябинская область, г. Катав-Ивановск...
# 41691  456110, Челябинская область, г. Катав-Ивановск...
#
# [35845 rows x 5 columns]

# %%
doc3=pd.read_excel('./data/Реестр лицензий на обращение с отходами 2.xls', sheet_name=0,header=1)
doc3=doc3[pd.isnull(doc3['Unnamed: 13'])]
doc3=doc3.dropna(subset=['Наименование предприятия (полное, сокращенное, фирменное), ФИО индивидуального предпринимателя'])

doc3
# Out:
#        Unnamed: 0                                         Unnamed: 1  \
# 0             612  Уральское межрегиональное управление Росприрод...
# 1             612  Уральское межрегиональное управление Росприрод...
# 2             612  Уральское межрегиональное управление Росприрод...
# 3             612  Уральское межрегиональное управление Росприрод...
# 4             612  Уральское межрегиональное управление Росприрод...
# ...           ...                                                ...
# 17725         665  Уральское межрегиональное управление Росприрод...
# 17726         665  Уральское межрегиональное управление Росприрод...
# 17727         665  Уральское межрегиональное управление Росприрод...
# 17728         665  Уральское межрегиональное управление Росприрод...
# 17729         665  Уральское межрегиональное управление Росприрод...
#
#       Наименование предприятия (полное, сокращенное, фирменное), ФИО индивидуального предпринимателя  \
# 0                         ИП Киселюк Владимир Михайлович
# 1                         ИП Киселюк Владимир Михайлович
# 2                         ИП Киселюк Владимир Михайлович
# 3                         ИП Киселюк Владимир Михайлович
# 4                         ИП Киселюк Владимир Михайлович
# ...                                                  ...
# 17725                                 ОАО "Челябвтормет"
# 17726                                 ОАО "Челябвтормет"
# 17727                                 ОАО "Челябвтормет"
# 17728                                 ОАО "Челябвтормет"
# 17729                                 ОАО "Челябвтормет"
#
#                                      Адрес          Телефон             ОГРН  \
# 0             Златоуст, ул.просвещения, 18  (3513) 66-54-40  304740410500024
# 1             Златоуст, ул.просвещения, 18  (3513) 66-54-40  304740410500024
# 2             Златоуст, ул.просвещения, 18  (3513) 66-54-40  304740410500024
# 3             Златоуст, ул.просвещения, 18  (3513) 66-54-40  304740410500024
# 4             Златоуст, ул.просвещения, 18  (3513) 66-54-40  304740410500024
# ...                                    ...              ...              ...
# 17725  г. Челябинск, ул. Автодорожная, 1 а        791-42-41    1027402554255
# 17726  г. Челябинск, ул. Автодорожная, 1 а        791-42-41    1027402554255
# 17727  г. Челябинск, ул. Автодорожная, 1 а        791-42-41    1027402554255
# 17728  г. Челябинск, ул. Автодорожная, 1 а        791-42-41    1027402554255
# 17729  г. Челябинск, ул. Автодорожная, 1 а        791-42-41    1027402554255
#
#          Unnamed: 6           Unnamed: 7 Unnamed: 8        Unnamed: 9  ...  \
# 0      740400398630  2019-11-14 00:00:00  бессрочно       (74)-8573-Т  ...
# 1      740400398630  2019-11-14 00:00:00  бессрочно       (74)-8573-Т  ...
# 2      740400398630  2019-11-14 00:00:00  бессрочно       (74)-8573-Т  ...
# 3      740400398630  2019-11-14 00:00:00  бессрочно       (74)-8573-Т  ...
# 4      740400398630  2019-11-14 00:00:00  бессрочно       (74)-8573-Т  ...
# ...             ...                  ...        ...               ...  ...
# 17725    7448009721  2020-09-22 00:00:00  бессрочно  (66)-740009-СТОУ  ...
# 17726    7448009721  2020-09-22 00:00:00  бессрочно  (66)-740009-СТОУ  ...
# 17727    7448009721  2020-09-22 00:00:00  бессрочно  (66)-740009-СТОУ  ...
# 17728    7448009721  2020-09-22 00:00:00  бессрочно  (66)-740009-СТОУ  ...
# 17729    7448009721  2020-09-22 00:00:00  бессрочно  (66)-740009-СТОУ  ...
#
#       Код отхода по ФККО Класс опасности отхода  \
# 0       9 20 110 01 53 2                     II
# 1       9 20 110 02 52 3                    III
# 2       9 20 110 03 51 3                    III
# 3       9 21 110 01 50 4                     IV
# 4       9 21 130 02 50 4                     IV
# ...                  ...                    ...
# 17725   4 69 522 13 51 4                     IV
# 17726   4 69 532 11 52 4                     IV
# 17727   4 69 541 11 51 4                     IV
# 17728   4 69 542 11 51 4                     IV
# 17729   4 69 541 21 51 4                     IV
#
#                                              Unnamed: 17  \
# 0          транспортирование отходов II класса опасности
# 1         транспортирование отходов III класса опасности
# 2      транспортирование отходов III класса          ...
# 3          Транспортирование отходов IV класса опасности
# 4          Транспортирование отходов IV класса опасности
# ...                                                  ...
# 17725  Сбор, транспортирование, обработка отходов 4 к...
# 17726  Сбор, транспортирование, обработка отходов 4 к...
# 17727  Сбор, транспортирование, обработка отходов 4 к...
# 17728  Сбор, транспортирование, обработка отходов 4 к...
# 17729  Сбор, транспортирование, обработка отходов 4 к...
#
#                                              Unnamed: 18  \
# 0      456208, Челябинская область, г. Златоуст, ул. ...
# 1      456208, Челябинская область, г. Златоуст, ул. ...
# 2      456208, Челябинская область, г. Златоуст, ул. ...
# 3      456208, Челябинская область, г. Златоуст, ул. ...
# 4      456208, Челябинская область, г. Златоуст, ул. ...
# ...                                                  ...
# 17725                 г. Челябинск, ул. Автодорожная, 1а
# 17726                 г. Челябинск, ул. Автодорожная, 1а
# 17727                 г. Челябинск, ул. Автодорожная, 1а
# 17728                 г. Челябинск, ул. Автодорожная, 1а
# 17729                 г. Челябинск, ул. Автодорожная, 1а
#
#       номер и дата проверки номер и дата выездной проверки Unnamed: 21  \
# 0        32-Ч от 01.11.2019             44-Ч от 13.11.2019         NaN
# 1        32-Ч от 01.11.2019             44-Ч от 13.11.2019         NaN
# 2        32-Ч от 01.11.2019             44-Ч от 13.11.2019         NaN
# 3        32-Ч от 01.11.2019             44-Ч от 13.11.2019         NaN
# 4        32-Ч от 01.11.2019             44-Ч от 13.11.2019         NaN
# ...                     ...                            ...         ...
# 17725   405-Ч от 15.09.2020            406-Ч от 18.09.2020         NaN
# 17726   405-Ч от 15.09.2020            406-Ч от 18.09.2020         NaN
# 17727   405-Ч от 15.09.2020            406-Ч от 18.09.2020         NaN
# 17728   405-Ч от 15.09.2020            406-Ч от 18.09.2020         NaN
# 17729   405-Ч от 15.09.2020            406-Ч от 18.09.2020         NaN
#
#       Unnamed: 22 Unnamed: 23  \
# 0             NaN         NaN
# 1             NaN         NaN
# 2             NaN         NaN
# 3             NaN         NaN
# 4             NaN         NaN
# ...           ...         ...
# 17725         NaN         NaN
# 17726         NaN         NaN
# 17727         NaN         NaN
# 17728         NaN         NaN
# 17729         NaN         NaN
#
#                                              Unnamed: 24
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 17725  переоформление лицензии на осуществление деяте...
# 17726  переоформление лицензии на осуществление деяте...
# 17727  переоформление лицензии на осуществление деяте...
# 17728  переоформление лицензии на осуществление деяте...
# 17729  переоформление лицензии на осуществление деяте...
#
# [17730 rows x 25 columns]

# %%
doc3.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1',
#        'Наименование предприятия (полное, сокращенное, фирменное), ФИО индивидуального предпринимателя',
#        'Адрес', 'Телефон', 'ОГРН', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Наименование отхода', 'Код отхода по ФККО',
#        'Класс опасности отхода', 'Unnamed: 17', 'Unnamed: 18',
#        'номер и дата проверки', 'номер и дата выездной проверки',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24'],
#       dtype='object')

# %%
doc3_my=doc3[['Наименование предприятия (полное, сокращенное, фирменное), ФИО индивидуального предпринимателя','ОГРН','Unnamed: 6','Unnamed: 17','Unnamed: 18']]
doc3_my.columns=['name','inn','ogrn','type','adres']

doc3_my
# Out:
#                                  name              inn          ogrn  \
# 0      ИП Киселюк Владимир Михайлович  304740410500024  740400398630
# 1      ИП Киселюк Владимир Михайлович  304740410500024  740400398630
# 2      ИП Киселюк Владимир Михайлович  304740410500024  740400398630
# 3      ИП Киселюк Владимир Михайлович  304740410500024  740400398630
# 4      ИП Киселюк Владимир Михайлович  304740410500024  740400398630
# ...                               ...              ...           ...
# 17725              ОАО "Челябвтормет"    1027402554255    7448009721
# 17726              ОАО "Челябвтормет"    1027402554255    7448009721
# 17727              ОАО "Челябвтормет"    1027402554255    7448009721
# 17728              ОАО "Челябвтормет"    1027402554255    7448009721
# 17729              ОАО "Челябвтормет"    1027402554255    7448009721
#
#                                                     type  \
# 0          транспортирование отходов II класса опасности
# 1         транспортирование отходов III класса опасности
# 2      транспортирование отходов III класса          ...
# 3          Транспортирование отходов IV класса опасности
# 4          Транспортирование отходов IV класса опасности
# ...                                                  ...
# 17725  Сбор, транспортирование, обработка отходов 4 к...
# 17726  Сбор, транспортирование, обработка отходов 4 к...
# 17727  Сбор, транспортирование, обработка отходов 4 к...
# 17728  Сбор, транспортирование, обработка отходов 4 к...
# 17729  Сбор, транспортирование, обработка отходов 4 к...
#
#                                                    adres
# 0      456208, Челябинская область, г. Златоуст, ул. ...
# 1      456208, Челябинская область, г. Златоуст, ул. ...
# 2      456208, Челябинская область, г. Златоуст, ул. ...
# 3      456208, Челябинская область, г. Златоуст, ул. ...
# 4      456208, Челябинская область, г. Златоуст, ул. ...
# ...                                                  ...
# 17725                 г. Челябинск, ул. Автодорожная, 1а
# 17726                 г. Челябинск, ул. Автодорожная, 1а
# 17727                 г. Челябинск, ул. Автодорожная, 1а
# 17728                 г. Челябинск, ул. Автодорожная, 1а
# 17729                 г. Челябинск, ул. Автодорожная, 1а
#
# [17730 rows x 5 columns]

# %%
doc4=pd.read_excel('./data/Реестр ПТО НВОС.xlsx', sheet_name=0)
doc4=doc4[pd.isnull(doc4['Дата исключения из реестра'])]
doc4=doc4.dropna(subset=['Местонахождение объекта'])

doc4
# Out:
#       № п/п  Код объекта НВОС  \
# 0         1  75-0274-001025-П
# 1         2  75-0274-001032-П
# 2         3  75-0274-001326-П
# 3         4  75-0174-001001-П
# 4         5  75-0274-001036-П
# ...     ...               ...
# 2984   2985  75-0274-003945-П
# 2985   2986  75-0274-003946-П
# 2986   2987  75-0274-003947-П
# 2987   2988  75-0174-002787-П
# 2988   2989  75-0274-003948-П
#
#                                    Наименование объекта       ОКТМО  \
# 0                                         ООО Полипласт  75701315.0
# 1                     ОАО "Кыштымский абразивный завод"  75734000.0
# 2                           Производственная территория  75626425.0
# 3     Промплощадка  Коркинский экскаваторо-вагонорем...  75633101.0
# 4                         ЧОБУ "Каслинское лесничество"  75626101.0
# ...                                                 ...         ...
# 2984                       ООО "Центр масел ОЙЛ-МАРКЕТ"  75701310.0
# 2985                                 Территория объекта  75619154.0
# 2986                          Производственная площадка  75701380.0
# 2987                                Очистные сооружения  75619154.0
# 2988          строительная площадка ООО "ИнвестХимАгро"  75715000.0
#
#                                 Местонахождение объекта  \
# 0                 г Челябинск, ул Молодогвардейцев, д 2
# 1     Челябинская область, г. Кыштым, ул. Станционна...
# 2     456844, Челябинская область, Каслинский район,...
# 3     456550, РФ, Челябинская область, Коркинский ра...
# 4         Челябинская область, г. Касли, ул. Ленина, 15
# ...                                                 ...
# 2984           г Челябинск, ул Братьев Кашириных, д 130
# 2985  Челябинская об., п.Красногорский, ул.Строитель...
# 2986              г Челябинск, ул Рождественского, д 13
# 2987  Челябинская область, Еманжелинский район, пос....
# 2988  Челябинская обл, г Карабаш, ул Освобождения Урала
#
#               Наименование\nэксплуатирующей организации  \
# 0     Общество с ограниченной ответственностью "Поли...
# 1     Открытое акционерное общество "Кыштымский абра...
# 2     Общество с ограниченной ответсвенностью "Щерба...
# 3     Общество с ограниченной ответственностью "Корк...
# 4     Челябинское областное бюджетное учреждение "Ка...
# ...                                                 ...
# 2984  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЦЕНТ...
# 2985  Общество с ограниченной ответственностью «Крас...
# 2986  Общество с ограниченной ответственностью «Техн...
# 2987  МУНИЦИПАЛЬНОЕ ПРЕДПРИЯТИЕ "ГОРОДСКОЕ КОММУНАЛЬ...
# 2988  Общество с ограниченной ответственностью «Инве...
#
#                                       Юридический адрес         ИНН  \
# 0     454014, Челябинск, г Челябинск, ул Молодогвард...  7448174764
# 1               456873, г. Кыштым, ул. Станционная, 1 А  7413007498
# 2     456844, Челябинская область, Каслинский р-н, с...  7459001259
# 3     456550, РФ, Челябинская область, Коркинский ра...  7412012791
# 4                      456835, г. Касли, ул. Ленина, 15  7402009920
# ...                                                 ...         ...
# 2984  450105, г Уфа, ул Маршала Жукова, д 39 к 3, по...   276959235
# 2985  454081, г Челябинск, ул Либединского, д 47А, кв 6  7452050225
# 2986     454091, г Челябинск, пр-кт Ленина, д 45, кв 15  7451273275
# 2987  456592, Челябинская обл, Еманжелинский р-н, рп...  7412014855
# 2988  456871, Челябинская обл, г Кыштым, ул Карла Ли...  7413026758
#
#                ОГРН              Орган, выдавший свидетельство  ...  \
# 0     1157448000379  Министерство экологии Челябинской области  ...
# 1     1027400827904  Министерство экологии Челябинской области  ...
# 2     1127459001394  Министерство экологии Челябинской области  ...
# 3     1087412001050  Министерство экологии Челябинской области  ...
# 4     1077402001060  Министерство экологии Челябинской области  ...
# ...             ...                                        ...  ...
# 2984  1210200002374  Министерство экологии Челябинской области  ...
# 2985  1067452024100  Министерство экологии Челябинской области  ...
# 2986  1087451013044  Министерство экологии Челябинской области  ...
# 2987  1107412000838  Министерство экологии Челябинской области  ...
# 2988  1197456049174  Министерство экологии Челябинской области  ...
#
#      Дата окончания разрешения на размещение отходов  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 2984                                             NaN
# 2985                                             NaN
# 2986                                             NaN
# 2987                                             NaN
# 2988                                             NaN
#
#       Кол-во объектов размещения отходов Суммарная масса отходов, т/год  \
# 0                                      0                            NaN
# 1                                      0                            NaN
# 2                                      0                            NaN
# 3                                      0                            NaN
# 4                                      0                            NaN
# ...                                  ...                            ...
# 2984                                   0                            NaN
# 2985                                   0                            NaN
# 2986                                   0                            NaN
# 2987                                   0                            NaN
# 2988                                   0                            NaN
#
#       Выбросы парниковых газов (СО2), т/год Дата постановки на учет  \
# 0                                  0.000000              2016-12-19
# 1                                  0.000000              2016-12-22
# 2                                  0.000000              2017-02-13
# 3                               5321.094000              2016-12-08
# 4                                  0.000000              2016-12-23
# ...                                     ...                     ...
# 2984                                    NaN              2021-10-25
# 2985                             285.269263              2021-10-25
# 2986                               0.000000              2021-10-25
# 2987                                    NaN              2021-10-27
# 2988                               0.000000              2021-10-27
#
#      Дата актуализации сведений  Дата исключения из реестра  \
# 0                    2021-04-29                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                    2020-12-04                         NaN
# 4                           NaN                         NaN
# ...                         ...                         ...
# 2984                        NaN                         NaN
# 2985                        NaN                         NaN
# 2986                        NaN                         NaN
# 2987                        NaN                         NaN
# 2988                        NaN                         NaN
#
#       Дата ввода в эксплуатацию  Водоохранная зона  Глубоководные выпуски
# 0                    1978-01-01                Нет                    NaN
# 1                    1988-01-01                Нет                    NaN
# 2                    1916-07-01                Нет                    NaN
# 3                    1944-07-01                Нет                    NaN
# 4                    2008-01-01                Нет                    NaN
# ...                         ...                ...                    ...
# 2984                 2021-05-01                Нет                    NaN
# 2985                 2006-09-01                Нет                    NaN
# 2986                 2020-01-01                Нет                    NaN
# 2987                 1972-10-10                Нет                    NaN
# 2988                        NaN                Нет                    NaN
#
# [2943 rows x 38 columns]

# %%
doc4.columns
# Out:
# Index(['№ п/п', 'Код объекта НВОС', 'Наименование объекта', 'ОКТМО',
#        'Местонахождение объекта', 'Наименование\nэксплуатирующей организации',
#        'Юридический адрес', 'ИНН', 'ОГРН', 'Орган, выдавший свидетельство',
#        'Контролирующий орган', 'ОКПД', 'ОКВЭД', 'Категория \nобъекта НВОС',
#        'Уровень реестра', 'Критерии присвоения категории НВОС ',
#        'Номер разрешения на выброс', 'Дата разрешения на выброс',
#        'Дата окончания разрешения на выброс', 'Кол-во \nисточников выбросов',
#        'Суммарный выброс, т/год', 'Номер разрешения на сброс',
#        'Дата разрешения на сброс', 'Дата окончания  разрешения на сброс',
#        'Кол-во сбросов', 'Суммарный сброс, т/год',
#        'Номер разрешения на размещение отходов',
#        'Дата разрешения на размещение отходов',
#        'Дата окончания разрешения на размещение отходов',
#        'Кол-во объектов размещения отходов', 'Суммарная масса отходов, т/год',
#        'Выбросы парниковых газов (СО2), т/год', 'Дата постановки на учет',
#        'Дата актуализации сведений', 'Дата исключения из реестра',
#        'Дата ввода в эксплуатацию', 'Водоохранная зона',
#        'Глубоководные выпуски'],
#       dtype='object')

# %%
doc4_my=doc4[['Наименование объекта','ИНН', 'ОГРН','Категория \nобъекта НВОС','Местонахождение объекта']]
doc4_my.columns=['name','inn','ogrn','type','adres']

doc4_my
# Out:
#                                                    name         inn  \
# 0                                         ООО Полипласт  7448174764
# 1                     ОАО "Кыштымский абразивный завод"  7413007498
# 2                           Производственная территория  7459001259
# 3     Промплощадка  Коркинский экскаваторо-вагонорем...  7412012791
# 4                         ЧОБУ "Каслинское лесничество"  7402009920
# ...                                                 ...         ...
# 2984                       ООО "Центр масел ОЙЛ-МАРКЕТ"   276959235
# 2985                                 Территория объекта  7452050225
# 2986                          Производственная площадка  7451273275
# 2987                                Очистные сооружения  7412014855
# 2988          строительная площадка ООО "ИнвестХимАгро"  7413026758
#
#                ogrn  type                                              adres
# 0     1157448000379     3              г Челябинск, ул Молодогвардейцев, д 2
# 1     1027400827904     3  Челябинская область, г. Кыштым, ул. Станционна...
# 2     1127459001394     3  456844, Челябинская область, Каслинский район,...
# 3     1087412001050     2  456550, РФ, Челябинская область, Коркинский ра...
# 4     1077402001060     3      Челябинская область, г. Касли, ул. Ленина, 15
# ...             ...   ...                                                ...
# 2984  1210200002374     4           г Челябинск, ул Братьев Кашириных, д 130
# 2985  1067452024100     3  Челябинская об., п.Красногорский, ул.Строитель...
# 2986  1087451013044     2              г Челябинск, ул Рождественского, д 13
# 2987  1107412000838     2  Челябинская область, Еманжелинский район, пос....
# 2988  1197456049174     3  Челябинская обл, г Карабаш, ул Освобождения Урала
#
# [2943 rows x 5 columns]

# %%
doc5=pd.read_excel('./data/Реестр разрешений на выбросы загрязняющих веществ -Минэкология.xlsx', sheet_name=0)
doc5=doc5.dropna(subset=['Юридический адрес / фактический адрес месторасположения'])

doc5
# Out:
#     № п/п (произв. площадки)  \
# 0                        NaN
# 1                          1
# 4                        NaN
# 6                        NaN
# 8                        NaN
# ..                       ...
# 791                       47
# 793                       48
# 795                       49
# 797                       50
# 799                       51
#
#     Наименование юридического лица (филиала по субъекту Российской Федерации), фамилия, имя, отчество индивидуального предпринимателя  \
# 0                                                  NaN
# 1                                                    2
# 4              ОАО «Инженерный центр энергетики Урала»
# 6              ОАО «Инженерный центр энергетики Урала»
# 8    ОАО «Научно-исследовательский институт металлу...
# ..                                                 ...
# 791                                        ООО «Лента»
# 793       ООО  «Региональная сеть предприятий питания»
# 795       ООО  «Региональная сеть предприятий питания»
# 797                              ПАО «Сбербанк России»
# 799                              ПАО «Сбербанк России»
#
#     Юридический адрес / фактический адрес месторасположения  \
# 0    (район города Челябинска определен из располож...
# 1                                                    3
# 4    620075, г. Екатеринбург, ул. Первомайская, д. ...
# 6    620075, г. Екатеринбург, ул. Первомайская, д. ...
# 8    454047, г. Челябинск, ул. 2-я Павелецкая,18/45...
# ..                                                 ...
# 791  197374, г. Санкт-Петербург, ул. Савушкина, д. ...
# 793  123022, г. Москва, ул. Красная Пресня, д. 31/2...
# 795  123022, г. Москва, ул. Красная Пресня, д. 31/2...
# 797  117997, г. Москва, ул. Вавилова, 19/454048, г....
# 799  117997, г. Москва, ул. Вавилова, 19/454048, г....
#
#      Идентификационный номер налогоплательщика  \
# 0                                          NaN
# 1                                          NaN
# 4                                 6.660002e+09
# 6                                 6.660002e+09
# 8                                 7.450001e+09
# ..                                         ...
# 791                               7.814148e+09
# 793                               7.703407e+09
# 795                               7.703407e+09
# 797                               7.707084e+09
# 799                               7.707084e+09
#
#     Номер и дата выдачи разрешения на выброс вредных (загрязняющих) веществ в атмосферный воздух  \
# 0                                                  NaN
# 1                                                  NaN
# 4                                    №59 от 22.04.2013
# 6                                    №59 от 22.04.2013
# 8                                   №105 от 01.07.2013
# ..                                                 ...
# 791                                   №1421 11.05.2018
# 793                                   №1426 14.05.2018
# 795                                   №1426 14.05.2018
# 797                                   №1443 07.06.2018
# 799                                   №1443 07.06.2018
#
#     Разрешенный выброс вредных (загрязняющих) веществ в пределах утвержденных нормативов ПДВ  \
# 0                                                  NaN
# 1                                                    5
# 4                                             0.021391
# 6                                              0.38241
# 8                                              41.4345
# ..                                                 ...
# 791                                            2.23211
# 793                                           0.023379
# 795                                           0.024774
# 797                                           0.036452
# 799                                           0.005993
#
#     (разбивка по веществам в тоннах)   Unnamed: 7    Unnamed: 8 Unnamed: 9  \
# 0                             аммиак  сероводород  формальдегид      фенол
# 1                                  6            7             8          9
# 4                                  Х            Х             Х          Х
# 6                                  Х            Х             Х          Х
# 8                                  Х            Х             Х          Х
# ..                               ...          ...           ...        ...
# 791                         0.015768      1.8e-06      0.000857          Х
# 793                                Х            Х             Х          Х
# 795                                Х            Х             Х          Х
# 797                                Х            Х      0.000143          Х
# 799                                Х            Х       2.6e-05          Х
#
#      ...  Unnamed: 22  Unnamed: 23  Unnamed: 24  Unnamed: 25  Unnamed: 26  \
# 0    ...          NaN          NaN          NaN          NaN          NaN
# 1    ...          NaN          NaN          NaN          NaN          NaN
# 4    ...          NaN          NaN          NaN          NaN          NaN
# 6    ...          NaN          NaN          NaN          NaN          NaN
# 8    ...          NaN          NaN          NaN          NaN          NaN
# ..   ...          ...          ...          ...          ...          ...
# 791  ...          NaN          NaN          NaN          NaN          NaN
# 793  ...          NaN          NaN          NaN          NaN          NaN
# 795  ...          NaN          NaN          NaN          NaN          NaN
# 797  ...          NaN          NaN          NaN          NaN          NaN
# 799  ...          NaN          NaN          NaN          NaN          NaN
#
#      Unnamed: 27  Unnamed: 28  Unnamed: 29  Unnamed: 30  Unnamed: 31
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN          NaN
# 6            NaN          NaN          NaN          NaN          NaN
# 8            NaN          NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 791          NaN          NaN          NaN          NaN          NaN
# 793          NaN          NaN          NaN          NaN          NaN
# 795          NaN          NaN          NaN          NaN          NaN
# 797          NaN          NaN          NaN          NaN          NaN
# 799          NaN          NaN          NaN          NaN          NaN
#
# [459 rows x 32 columns]

# %%
doc5['vred']=str(doc5['(разбивка по веществам в тоннах)'])+str(doc5['Unnamed: 7'])+str(doc5['Unnamed: 8'])

# %%
doc5['vred']
# Out:
# 0      0        аммиак\n1             6\n4           ...
# 1      0        аммиак\n1             6\n4           ...
# 4      0        аммиак\n1             6\n4           ...
# 6      0        аммиак\n1             6\n4           ...
# 8      0        аммиак\n1             6\n4           ...
#                              ...
# 791    0        аммиак\n1             6\n4           ...
# 793    0        аммиак\n1             6\n4           ...
# 795    0        аммиак\n1             6\n4           ...
# 797    0        аммиак\n1             6\n4           ...
# 799    0        аммиак\n1             6\n4           ...
# Name: vred, Length: 459, dtype: object

# %%
doc5.columns
# Out:
# Index(['№ п/п (произв. площадки)',
#        'Наименование юридического лица (филиала по субъекту Российской Федерации), фамилия, имя, отчество индивидуального предпринимателя',
#        'Юридический адрес / фактический адрес месторасположения',
#        'Идентификационный номер налогоплательщика',
#        'Номер и дата выдачи разрешения на выброс вредных (загрязняющих) веществ в атмосферный воздух',
#        'Разрешенный выброс вредных (загрязняющих) веществ в пределах утвержденных нормативов ПДВ',
#        '(разбивка по веществам в тоннах)', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'vred'],
#       dtype='object')

# %%
doc5_my=doc5[['Наименование юридического лица (филиала по субъекту Российской Федерации), фамилия, имя, отчество индивидуального предпринимателя','Идентификационный номер налогоплательщика', 'Номер и дата выдачи разрешения на выброс вредных (загрязняющих) веществ в атмосферный воздух','vred','Юридический адрес / фактический адрес месторасположения']]
doc5_my.columns=['name','inn','ogrn','type','adres']
doc5_my
# Out:
#                                                   name           inn  \
# 0                                                  NaN           NaN
# 1                                                    2           NaN
# 4              ОАО «Инженерный центр энергетики Урала»  6.660002e+09
# 6              ОАО «Инженерный центр энергетики Урала»  6.660002e+09
# 8    ОАО «Научно-исследовательский институт металлу...  7.450001e+09
# ..                                                 ...           ...
# 791                                        ООО «Лента»  7.814148e+09
# 793       ООО  «Региональная сеть предприятий питания»  7.703407e+09
# 795       ООО  «Региональная сеть предприятий питания»  7.703407e+09
# 797                              ПАО «Сбербанк России»  7.707084e+09
# 799                              ПАО «Сбербанк России»  7.707084e+09
#
#                    ogrn                                               type  \
# 0                   NaN  0        аммиак\n1             6\n4           ...
# 1                   NaN  0        аммиак\n1             6\n4           ...
# 4     №59 от 22.04.2013  0        аммиак\n1             6\n4           ...
# 6     №59 от 22.04.2013  0        аммиак\n1             6\n4           ...
# 8    №105 от 01.07.2013  0        аммиак\n1             6\n4           ...
# ..                  ...                                                ...
# 791    №1421 11.05.2018  0        аммиак\n1             6\n4           ...
# 793    №1426 14.05.2018  0        аммиак\n1             6\n4           ...
# 795    №1426 14.05.2018  0        аммиак\n1             6\n4           ...
# 797    №1443 07.06.2018  0        аммиак\n1             6\n4           ...
# 799    №1443 07.06.2018  0        аммиак\n1             6\n4           ...
#
#                                                  adres
# 0    (район города Челябинска определен из располож...
# 1                                                    3
# 4    620075, г. Екатеринбург, ул. Первомайская, д. ...
# 6    620075, г. Екатеринбург, ул. Первомайская, д. ...
# 8    454047, г. Челябинск, ул. 2-я Павелецкая,18/45...
# ..                                                 ...
# 791  197374, г. Санкт-Петербург, ул. Савушкина, д. ...
# 793  123022, г. Москва, ул. Красная Пресня, д. 31/2...
# 795  123022, г. Москва, ул. Красная Пресня, д. 31/2...
# 797  117997, г. Москва, ул. Вавилова, 19/454048, г....
# 799  117997, г. Москва, ул. Вавилова, 19/454048, г....
#
# [459 rows x 5 columns]

# %%
my_data=pd.concat([doc1_my, doc2_my,doc3_my,doc4_my,doc5_my], axis=0)
my_data['adres']=my_data['adres'].str.replace('\n', ' ')

# %%
my_data.to_excel("my_data.xlsx",
             sheet_name='Sheet_name_1')
